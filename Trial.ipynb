# %% [markdown]
# # ここ
# ## で初めてのマークダウン
# ### を使用します

# %%
import matplotlib.pyplot as plt

price = [100, 250, 300, 500, 700]
number = [1, 2, 3, 4, 5]

plt.plot(price, number)

plt.title("price / number")

plt.xlabel("price")

plt.ylabel("number")

plt.show()
